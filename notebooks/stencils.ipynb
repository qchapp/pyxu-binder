# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
from pyxu.operator import Convolve

# %% [markdown]
# # Convolution with Pyxu

# %% [markdown]
# ## 0) Install dependencies

# %% [markdown]
# You'll need some additional dependencies to run this example:
#
# * tqdm (https://tqdm.github.io/)
# * scico (https://scico.readthedocs.io/en/latest/index.html)
# * pylops (https://pylops.readthedocs.io/en/stable/index.html)
#
# Warning: this notebook benchmarks different packages and can take a few minutes to execute.

# %% [markdown]
# ## 1) Prepare data

# %% [markdown]
# #### Create input image
#
# We first start creating a 2D binary image of size 128x128 with blobs, where the blobs occupy approximately 20% of the
# image's area and are about half the size of the image.
#
# The resulting binary image is then converted to a floating-point representation.

# %%
npix = 128
data = skimage.data.binary_blobs(
    length=npix, 
    blob_size_fraction=0.5, 
    n_dim=2, 
    volume_fraction=0.2,
).astype(float)

# %% [markdown]
# #### Create blurring kernel

# %%
sigma = 2  # Gaussian kernel std
width = 11  # Length of the Graussian kernel
gauss = lambda x: (1 / (2 * np.pi * sigma**2)) * np.exp(
    -0.5 * ((x - (width - 1) / 2) ** 2) / (sigma**2)
)
kernel_1d = np.fromfunction(gauss, (width,))
kernel_2d = np.outer(kernel_1d.reshape(-1, 1), kernel_1d.reshape(1, -1))

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].imshow(data)
axs[0].set_title("Original image")

axs[1].plot(kernel_1d)
axs[1].set_title("1D Gaussian kernel")

axs[2].imshow(kernel_2d)
axs[2].set_title("2D Gaussian kernel")

fig.tight_layout();

# %% [markdown]
# ## 2) Convolve image

# %% [markdown]
# #### Scipy
#
# If you want to use `scipy.signal.convolve()` to perform 2D convolutions, it expects the kernel to match the dimensionality of
# the input data. So, for 2D data, you would generally provide a 2D kernel.

# %%
from scipy.signal import convolve as conv_scipy

# Direct 2D convolution
y = conv_scipy(data, kernel_2d, mode="same", method="direct")

# %% [markdown]
# However, when dealing with a separable kernel (like a Gaussian kernel), you can take advantage of the kernel's
# separability to perform convolution more efficiently:
#
# - First, convolve the input 2D data with the 1D kernel along one dimension (e.g., rows).
# - Then, convolve the result from the first step with the same 1D kernel along the other dimension (e.g., columns).

# %%
# Separable convolution ...

convolved_rows = conv_scipy(  # ... along rows
    data, 
    kernel_1d[:, np.newaxis], 
    mode="same", 
    method="direct",
)

y_separable = conv_scipy(  # ... then along columns
    convolved_rows, 
    kernel_1d[np.newaxis, :], 
    mode="same", 
    method="direct",
)

assert np.allclose(y, y_separable)

# %% [markdown]
# #### Pyxu
#
# Pyxu is optimized to handle separable kernels, which enhances performance. When working with such kernels, Pyxu can
# directly manage the separable convolution. Additionally, Pyxu leverages
# [Numba.stencil](https://numba.pydata.org/numba-doc/latest/user/stencil.html) to just-in-time (JIT) compile the
# convolution under the hood to make it faster. Here's how you can use it:

# %%
conv = Convolve(
    dim_shape=data.shape,
    kernel=[kernel_1d, kernel_1d],
    center=[width // 2, width // 2],
    mode="constant",
    enable_warnings=True,
)
y_pyxu = conv(data)

assert np.allclose(y, y_pyxu)

# %% [markdown]
# #### PyLops
#
# PyLops uses a flattened (raveled) version of your 2D data when applying the linear operator, so you need to flatten and
# reshape your data as you move between operations. If you want to perform a separable convolution, you need to manually
# decompose the 2D kernel into two 1D kernels, then apply two separate 1D convolution operations sequentially. This adds
# an extra layer of complexity in the implementation compared to just using a 2D convolution directly.

# %%
# !pip install pylops
# Out:
# Collecting pylops
#   Downloading pylops-2.5.0-py3-none-any.whl (320 kB)
#      -------------------------------------- 320.7/320.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from pylops) (2.0.2)
# Requirement already satisfied: scipy>=1.11.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from pylops) (1.15.2)
# Installing collected packages: pylops
# Successfully installed pylops-2.5.0
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyxu.operator.interop import from_sciop
import pyxu.abc as pxa

from pylops.signalprocessing import Convolve2D

# 2d convolution
conv_pylops = from_sciop(
    cls=pxa.LinOp,
    sp_op=Convolve2D(
        dims=data.shape,
        h=kernel_2d,
        offset=np.r_[width // 2, width // 2],
        axes=(0, 1),
        method="direct",
    ),
)
y_pylops = conv_pylops(data.ravel()).reshape(data.shape)
assert np.allclose(y, y_pylops)

# %%
# Separable convolution
conv_pylops_rows = from_sciop(
    cls=pxa.LinOp,
    sp_op=Convolve2D(
        dims=data.shape,
        h=kernel_1d[np.newaxis, :],
        offset=np.r_[0, width // 2],
        axes=(0, 1),
        method="direct",
    ),
)
conv_pylops_cols = from_sciop(
    cls=pxa.LinOp,
    sp_op=Convolve2D(
        dims=data.shape,
        h=kernel_1d[:, np.newaxis],
        offset=np.r_[width // 2, 0],
        axes=(0, 1),
        method="direct",
    ),
)

y_pylops = conv_pylops_cols(conv_pylops_rows(data.ravel())).reshape(data.shape)
assert np.allclose(y, y_pylops)

# %% [markdown]
# #### Scico
#
# Like Pyxu, Scico employs JIT (Just-In-Time) compilation to speed up convolution operations. However, Scico relies on Jax
# instead of Numba. This necessitates the transition of our array module from NumPy to Jax.
#
# In a manner similar to PyLops, Scico expects the convolutional kernel to have the same dimensionality as the input
# image. One can opt for a more efficient combination of two 1D operators or a simpler single 2D operator.

# %%
# !pip install scico
# Out:
# Collecting scico
#   Downloading scico-0.0.6-py3-none-any.whl (11.4 MB)
#      --------------------------------------- 11.4/11.4 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from scico) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from scico) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from scico) (1.15.2)
# Requirement already satisfied: imageio>=2.17 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from scico) (2.37.0)
# Requirement already satisfied: tifffile in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from scico) (2025.3.30)
# Requirement already satisfied: matplotlib in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from scico) (3.10.1)
# Collecting jaxlib<=0.4.35,>=0.4.13
#   Downloading jaxlib-0.4.35-cp311-cp311-win_amd64.whl (56.5 MB)
#      --------------------------------------- 56.5/56.5 MB 18.2 MB/s eta 0:00:00
# Collecting jax<=0.4.35,>=0.4.13
#   Downloading jax-0.4.35-py3-none-any.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 17.2 MB/s eta 0:00:00
# Collecting orbax-checkpoint>=0.5.0
#   Downloading orbax_checkpoint-0.11.16-py3-none-any.whl (477 kB)
#      -------------------------------------- 477.6/477.6 kB 9.9 MB/s eta 0:00:00
# Collecting flax<=0.10.0,>=0.8.0
#   Downloading flax-0.10.0-py3-none-any.whl (420 kB)
#      ------------------------------------- 420.2/420.2 kB 13.2 MB/s eta 0:00:00
# Collecting pyabel>=0.9.0
#   Downloading PyAbel-0.9.0.tar.gz (162 kB)
#      -------------------------------------- 162.2/162.2 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: msgpack in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from flax<=0.10.0,>=0.8.0->scico) (1.1.0)
# Collecting optax
#   Downloading optax-0.2.5-py3-none-any.whl (354 kB)
#      ------------------------------------- 354.3/354.3 kB 11.1 MB/s eta 0:00:00
# Collecting tensorstore
#   Downloading tensorstore-0.1.75-cp311-cp311-win_amd64.whl (12.6 MB)
#      --------------------------------------- 12.6/12.6 MB 19.8 MB/s eta 0:00:00
# Collecting rich>=11.1
#   Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from flax<=0.10.0,>=0.8.0->scico) (6.0.2)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from imageio>=2.17->scico) (11.2.1)
# Collecting ml-dtypes>=0.4.0
#   Downloading ml_dtypes-0.5.1-cp311-cp311-win_amd64.whl (209 kB)
#      ------------------------------------- 209.7/209.7 kB 12.5 MB/s eta 0:00:00
# Collecting opt-einsum
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting absl-py
#   Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
#      -------------------------------------- 135.7/135.7 kB 8.4 MB/s eta 0:00:00
# Collecting etils[epath,epy]
#   Downloading etils-1.12.2-py3-none-any.whl (167 kB)
#      -------------------------------------- 167.6/167.6 kB 9.8 MB/s eta 0:00:00
# Collecting orbax-checkpoint>=0.5.0
#   Downloading orbax_checkpoint-0.11.15-py3-none-any.whl (477 kB)
#      -------------------------------------- 477.5/477.5 kB 7.5 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.14-py3-none-any.whl (469 kB)
#      -------------------------------------- 470.0/470.0 kB 9.8 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.13-py3-none-any.whl (442 kB)
#      -------------------------------------- 442.7/442.7 kB 9.2 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.12-py3-none-any.whl (406 kB)
#      -------------------------------------- 406.3/406.3 kB 8.4 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.11-py3-none-any.whl (403 kB)
#      ------------------------------------- 403.8/403.8 kB 12.7 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.10-py3-none-any.whl (376 kB)
#      -------------------------------------- 376.9/376.9 kB 7.8 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.9-py3-none-any.whl (375 kB)
#      ------------------------------------- 375.8/375.8 kB 11.8 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.8-py3-none-any.whl (370 kB)
#      ------------------------------------- 370.2/370.2 kB 11.6 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.7-py3-none-any.whl (369 kB)
#      ------------------------------------- 369.6/369.6 kB 11.6 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.6-py3-none-any.whl (361 kB)
#      ------------------------------------- 361.8/361.8 kB 11.3 MB/s eta 0:00:00
#   Downloading orbax_checkpoint-0.11.5-py3-none-any.whl (342 kB)
#      ------------------------------------- 342.8/342.8 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: nest_asyncio in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from orbax-checkpoint>=0.5.0->scico) (1.6.0)
# Collecting protobuf
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
#      -------------------------------------- 435.3/435.3 kB 9.0 MB/s eta 0:00:00
# Collecting humanize
#   Downloading humanize-4.12.3-py3-none-any.whl (128 kB)
#      -------------------------------------- 128.5/128.5 kB 7.4 MB/s eta 0:00:00
# Collecting simplejson>=3.16.0
#   Downloading simplejson-3.20.1-cp311-cp311-win_amd64.whl (75 kB)
#      ---------------------------------------- 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=44.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from pyabel>=0.9.0->scico) (65.5.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from pyabel>=0.9.0->scico) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from matplotlib->scico) (2.9.0.post0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from rich>=11.1->flax<=0.10.0,>=0.8.0->scico) (2.19.1)
# Requirement already satisfied: fsspec in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from etils[epath,epy]->orbax-checkpoint>=0.5.0->scico) (2025.3.2)
# Collecting importlib_resources
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: zipp in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from etils[epath,epy]->orbax-checkpoint>=0.5.0->scico) (3.21.0)
# Collecting chex>=0.1.87
#   Downloading chex-0.1.89-py3-none-any.whl (99 kB)
#      ---------------------------------------- 99.9/99.9 kB ? eta 0:00:00
# Requirement already satisfied: toolz>=0.9.0 in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from chex>=0.1.87->optax->flax<=0.10.0,>=0.8.0->scico) (1.0.0)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: simplejson, protobuf, opt-einsum, ml-dtypes, mdurl, importlib_resources, humanize, etils, absl-py, tensorstore, pyabel, markdown-it-py, jaxlib, rich, jax, orbax-checkpoint, chex, optax, flax, scico
#   Running setup.py install for pyabel: started
#   Running setup.py install for pyabel: finished with status 'done'
# Successfully installed absl-py-2.3.0 chex-0.1.89 etils-1.12.2 flax-0.10.0 humanize-4.12.3 importlib_resources-6.5.2 jax-0.4.35 jaxlib-0.4.35 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 opt-einsum-3.4.0 optax-0.2.5 orbax-checkpoint-0.11.5 protobuf-6.31.1 pyabel-0.9.0 rich-14.0.0 scico-0.0.6 simplejson-3.20.1 tensorstore-0.1.75
#   DEPRECATION: pyabel is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scico.linop import Convolve as Conv_scico
from jax import config
import jax.numpy as jnp

# Convert data and kernel from Numpy to Jax
data_jax = jnp.asarray(data)
k2d_jax = jnp.asarray(kernel_2d)
config.update("jax_enable_x64", True)

# 2d convolution
conv_scico = Conv_scico(
    k2d_jax,
    input_shape=data_jax.shape,
    input_dtype=data_jax.dtype,
    mode="same",
    jit=True,
)
y_scico = conv_scico(data_jax)
assert np.allclose(y, y_scico)

# %%
# Separable convolution
k1d_jax = jnp.asarray(kernel_1d)

conv_scico_rows = Conv_scico(
    k1d_jax[np.newaxis, :],
    input_shape=data_jax.shape,
    input_dtype=data_jax.dtype,
    mode="same",
    jit=True,
)
conv_scico_cols = Conv_scico(
    k1d_jax[:, np.newaxis],
    input_shape=data_jax.shape,
    input_dtype=data_jax.dtype,
    mode="same",
    jit=True,
)
y_scico = conv_scico_cols(conv_scico_rows(data_jax))
assert np.allclose(y, y_scico)

# %% [markdown]
# ## 3) Benchmark convolution runtime across all libraries

# %% [markdown]
# #### Separable 1d convolution

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in c:\users\qchap\onedrive\donnees\epfl\imaging-lab\pyxu-binder\env\lib\site-packages (from tqdm) (0.4.6)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
import tqdm

npixs = [2**i for i in range(6, 10)]
nwidths = [2**i + 1 for i in range(3, 8)]

t_pyxu = np.full((2, len(npixs), len(nwidths)), np.nan)
t_scipy = np.full((2, len(npixs), len(nwidths)), np.nan)
t_pylops = np.full((2, len(npixs), len(nwidths)), np.nan)
t_scico = np.full((2, len(npixs), len(nwidths)), np.nan)

sigma = 2
gauss = lambda x: (1 / (2 * np.pi * sigma**2)) * np.exp(
    -0.5 * ((x - (width - 1) / 2) ** 2) / (sigma**2)
)

nreps = 5

with tqdm.tqdm(total=len(npixs) * len(nwidths)) as pbar:
    for i, npix in enumerate(npixs):
        x = skimage.data.binary_blobs(
            length=npix, blob_size_fraction=0.5, n_dim=2, volume_fraction=0.2
        ).astype(float)
        for j, width in enumerate(nwidths):
            if npix > (width * 2):
                kernel = np.fromfunction(gauss, (width,))
                data_jax = jnp.asarray(data)
                k1d_jax = jnp.asarray(kernel_1d)

                ## PYXU

                # Instantation + first run time
                tic = time.perf_counter()
                conv_pyxu = Convolve(
                    dim_shape=data.shape,
                    kernel=[kernel, kernel],
                    center=[width // 2, width // 2],
                    mode="constant",
                    enable_warnings=True,
                )
                y = conv_pyxu(data)
                t_pyxu[0, i, j] = time.perf_counter() - tic

                # Run time
                times = 0
                for _ in range(nreps):
                    tic = time.perf_counter()
                    y = conv_pyxu(data)
                    times += time.perf_counter() - tic

                t_pyxu[1, i, j] = times / nreps

                ## SCIPY

                # Instantation + first run time
                tic = time.perf_counter()
                convolved_rows = conv_scipy(
                    data, kernel_1d[:, np.newaxis], mode="same", method="direct"
                )  # Along rows
                y_scipy = conv_scipy(
                    convolved_rows,
                    kernel_1d[np.newaxis, :],
                    mode="same",
                    method="direct",
                )  # Along columns

                t_scipy[0, i, j] = time.perf_counter() - tic

                # Run time
                times = 0
                for _ in range(nreps):
                    tic = time.perf_counter()
                    convolved_rows = conv_scipy(
                        data, kernel_1d[:, np.newaxis], mode="same", method="direct"
                    )  # Along rows
                    y_scipy = conv_scipy(
                        convolved_rows,
                        kernel_1d[np.newaxis, :],
                        mode="same",
                        method="direct",
                    )  # Along columns
                    times += time.perf_counter() - tic

                t_scipy[1, i, j] = times / nreps

                ## PYLOPS

                # Instantation + first run time
                tic = time.perf_counter()
                conv_pylops_rows = from_sciop(
                    cls=pxa.LinOp,
                    sp_op=Convolve2D(
                        dims=data.shape,
                        h=kernel_1d[np.newaxis, :],
                        offset=np.r_[0, width // 2],
                        axes=(0, 1),
                        method="direct",
                    ),
                )
                conv_pylops_cols = from_sciop(
                    cls=pxa.LinOp,
                    sp_op=Convolve2D(
                        dims=data.shape,
                        h=kernel_1d[:, np.newaxis],
                        offset=np.r_[width // 2, 0],
                        axes=(0, 1),
                        method="direct",
                    ),
                )

                y_pylops = conv_pylops_cols(conv_pylops_rows(data.ravel())).reshape(
                    data.shape
                )
                t_pylops[0, i, j] = time.perf_counter() - tic

                # Run time
                times = 0
                for _ in range(nreps):
                    tic = time.perf_counter()
                    y_pylops = conv_pylops_cols(conv_pylops_rows(data.ravel())).reshape(
                        data.shape
                    )
                    times += time.perf_counter() - tic
                t_pylops[1, i, j] = times / nreps

                ## SCICO

                # Instantation + first run time

                tic = time.perf_counter()
                config.update("jax_enable_x64", True)

                conv_scico_rows = Conv_scico(
                    k1d_jax[np.newaxis, :],
                    input_shape=data_jax.shape,
                    input_dtype=data_jax.dtype,
                    mode="same",
                    jit=True,
                )
                conv_scico_cols = Conv_scico(
                    k1d_jax[:, np.newaxis],
                    input_shape=data_jax.shape,
                    input_dtype=data_jax.dtype,
                    mode="same",
                    jit=True,
                )
                y_scico = conv_scico_cols(conv_scico_rows(data_jax))
                t_scico[0, i, j] = time.perf_counter() - tic

                # Run time
                times = 0
                for _ in range(nreps):
                    tic = time.perf_counter()
                    y_scico = conv_scico_cols(conv_scico_rows(data_jax))
                    times += time.perf_counter() - tic
                t_scico[1, i, j] = times / nreps
            pbar.update(1)
# Out:
# 100%|██████████| 20/20 [00:11<00:00,  1.70it/s]

# %%
fig, axs = plt.subplots(2, 4, figsize=(15, 5))
im = axs[0, 0].imshow(np.log10(t_pyxu[0]))
axs[0, 0].set_title("pyxu: t-init")
plt.colorbar(im, ax=axs[0, 0])

im = axs[0, 1].imshow(np.log10(t_scipy[0]))
axs[0, 1].set_title("scipy: t-init")
plt.colorbar(im, ax=axs[0, 1])

im = axs[0, 2].imshow(np.log10(t_pylops[0]))
axs[0, 2].set_title("pylops: t-init")
plt.colorbar(im, ax=axs[0, 2])


im = axs[0, 3].imshow(np.log10(t_scico[0]))
axs[0, 3].set_title("scico: t-init")
plt.colorbar(im, ax=axs[0, 3])

im = axs[1, 0].imshow(np.log10(t_pyxu[1]))
axs[1, 0].set_title("pyxu: t-run")
plt.colorbar(im, ax=axs[1, 0])

im = axs[1, 1].imshow(np.log10(t_scipy[1]))
axs[1, 1].set_title("scipy: t-run")
plt.colorbar(im, ax=axs[1, 1])

im = axs[1, 2].imshow(np.log10(t_pylops[1]))
axs[1, 2].set_title("pylops: t-run")
plt.colorbar(im, ax=axs[1, 2])

im = axs[1, 3].imshow(np.log10(t_scico[1]))
axs[1, 3].set_title("scico: t-run")
plt.colorbar(im, ax=axs[1, 3])

for ax in axs.ravel():
    ax.set_xticks(np.arange(len(nwidths)))
    ax.set_xticklabels(nwidths)
    ax.set_xlabel("Kernel width (1D)")
    ax.set_yticks(np.arange(len(npixs)))
    ax.set_yticklabels(npixs)
    ax.set_ylabel("N-pixels (1D)")

fig.suptitle(
    f"2D convolution (time in log-scale: t-init includes JIT compilation, t-run is the mean runtime across {nreps} reps)"
)
fig.tight_layout();

# %% [markdown]
# #### Direct 2d convolution

# %%
fig, axs = plt.subplots(2, 4, figsize=(15, 5))

im = axs[0, 0].imshow(np.log10(t_pyxu[0]))
axs[0, 0].set_title("pyxu: t-init")
plt.colorbar(im, ax=axs[0, 0])

im = axs[0, 1].imshow(np.log10(t_scipy[0]))
axs[0, 1].set_title("scipy: t-init")
plt.colorbar(im, ax=axs[0, 1])

im = axs[0, 2].imshow(np.log10(t_pylops[0]))
axs[0, 2].set_title("pylops: t-init")
plt.colorbar(im, ax=axs[0, 2])


im = axs[0, 3].imshow(np.log10(t_scico[0]))
axs[0, 3].set_title("scico: t-init")
plt.colorbar(im, ax=axs[0, 3])

im = axs[1, 0].imshow(np.log10(t_pyxu[1]))
axs[1, 0].set_title("pyxu: t-run")
plt.colorbar(im, ax=axs[1, 0])

im = axs[1, 1].imshow(np.log10(t_scipy[1]))
axs[1, 1].set_title("scipy: t-run")
plt.colorbar(im, ax=axs[1, 1])

im = axs[1, 2].imshow(np.log10(t_pylops[1]))
axs[1, 2].set_title("pylops: t-run")
plt.colorbar(im, ax=axs[1, 2])

im = axs[1, 3].imshow(np.log10(t_scico[1]))
axs[1, 3].set_title("scico: t-run")
plt.colorbar(im, ax=axs[1, 3])

for ax in axs.ravel():
    ax.set_xticks(np.arange(len(nwidths)))
    ax.set_xticklabels(nwidths)
    ax.set_xlabel("Kernel width (1D)")
    ax.set_yticks(np.arange(len(npixs)))
    ax.set_yticklabels(npixs)
    ax.set_ylabel("N-pixels (1D)")

fig.suptitle(
    f"2D convolution (time in log-scale: t-init includes JIT compilation, t-run is the mean runtime across {nreps} reps)"
)
fig.tight_layout();
